# %%
import pandas as pd
import os

def analyser_structure_fichier():
    print("=== ANALYSE DE LA STRUCTURE DU FICHIER ===")
    
    chemin_fichier = 'hackaton_projet_W3D5/DATASET/plats_populaires_ingredients.csv'
    
    try:
        # Lecture du fichier avec différents séparateurs
        print("\nTentative de lecture avec différents séparateurs...")
        
        # Essai avec point-virgule
        df_semicolon = pd.read_csv(chemin_fichier, sep=';', nrows=5)
        print("\nLecture avec point-virgule :")
        print("Colonnes trouvées :", df_semicolon.columns.tolist())
        print("\nPremières lignes :")
        print(df_semicolon.head(2))
        
        # Essai avec virgule
        df_comma = pd.read_csv(chemin_fichier, sep=',', nrows=5)
        print("\nLecture avec virgule :")
        print("Colonnes trouvées :", df_comma.columns.tolist())
        print("\nPremières lignes :")
        print(df_comma.head(2))
        
        # Affichage des informations détaillées
        print("\nInformations détaillées du DataFrame :")
        print(df_semicolon.info())
        
        # Vérification des valeurs nulles
        print("\nVérification des valeurs manquantes :")
        print(df_semicolon.isnull().sum())
        
    except Exception as e:
        print(f"Erreur lors de l'analyse : {e}")

# Exécution
if __name__ == "__main__":
    analyser_structure_fichier()
# Out:
# === ANALYSE DE LA STRUCTURE DU FICHIER ===
#
# Tentative de lecture avec différents séparateurs...
#
# Lecture avec point-virgule :
# Colonnes trouvées : ['Plat,Pays,Catégorie,Ingrédients,Nombre_Ingrédients']
#
# Premières lignes :
#   Plat,Pays,Catégorie,Ingrédients,Nombre_Ingrédients
# 0  Beef Brisket Pot Roast,ÉTATS-UNIS,Viande,Beef ...
# 1  Big Mac,ÉTATS-UNIS,Fast-food,Minced Beef (400g...
#
# Lecture avec virgule :
# Colonnes trouvées : ['Plat', 'Pays', 'Catégorie', 'Ingrédients', 'Nombre_Ingrédients']
#
# Premières lignes :
#                      Plat        Pays  Catégorie  \
# 0  Beef Brisket Pot Roast  ÉTATS-UNIS     Viande
# 1                 Big Mac  ÉTATS-UNIS  Fast-food
#
#                                          Ingrédients  Nombre_Ingrédients
# 0  Beef Brisket (4-5 pound) | Salt (Dash) | Onion...                  11
# 1  Minced Beef (400g) | Olive Oil (2 tbs) | Sesam...                  14
#
# Informations détaillées du DataFrame :
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 1 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Plat,Pays,Catégorie,Ingrédients,Nombre_Ingrédients  5 non-null      object
# dtypes: object(1)
# memory usage: 172.0+ bytes
# None
#
# Vérification des valeurs manquantes :
# Plat,Pays,Catégorie,Ingrédients,Nombre_Ingrédients    0
# dtype: int64

# %%
import os
import pandas as pd
import requests
import time
from typing import Dict, List, Tuple

class NutrientAnalyzer:
    def __init__(self):
        self.API_KEY = "V47bTvrwdE63sv3FPzRPbyo30fxLmg4cJnc6tWol"
        self.base_url = "https://api.nal.usda.gov/fdc/v1/foods/search"
        
        # Nutriments à analyser avec les termes exacts de l'API USDA
        self.nutriments_cibles = {
            'Protein': 'Protéines (g)',
            'Total lipid (fat)': 'Lipides (g)',
            'Carbohydrate, by difference': 'Glucides (g)',
            'Energy': 'Calories (kcal)',
            'Fiber, total dietary': 'Fibres (g)',
            'Sugars, total': 'Sucres (g)',
            'Sodium, Na': 'Sodium (mg)'
        }
        
        # Portions standard pour les ingrédients
        self.portions_standard = {
            # Viandes et Volailles
            'chicken': 150,              # g par portion standard
            'chicken breast': 170,       # g par poitrine
            'chicken legs': 230,         # g par cuisse
            'chicken thighs': 160,       # g par haut de cuisse
            'chicken wings': 50,         # g par ailette
            'chicken drumsticks': 100,   # g par pilon
            'beef': 200,                # g par portion
            'beef brisket': 450,        # g par portion
            'ground beef': 115,          # g par portion
            'ground turkey': 115,        # g par portion
            'ground pork': 100,         # g par portion
            'ground lamb': 100,         # g par portion
            'pork': 200,                # g par portion
            'pork chops': 200,          # g par côtelette
            'pork tenderloin': 100,     # g par portion
            'bacon': 30,                # g par tranche
            'lamb': 175,                # g par portion
            'lamb leg': 750,            # g par gigot
            'lamb mince': 125,          # g par portion
            'duck': 200,                # g par portion
            'veal': 300,                # g par jarret
            'veal shanks': 750,         # g par portion (osso buco)
            'rib-eye steaks': 225,      # g par steak (8 oz)

            # Fruits de Mer et Poissons
            'salmon': 150,              # g par portion
            'whitefish fillets': 100,   # g par portion
            'prawns': 30,               # g par pièce
            'king prawns': 30,          # g par pièce
            'clams': 100,               # g par portion
            'shrimp': 100,              # g par portion
            'mussels': 100,             # g par portion
            'lobster': 150,             # g par portion
            'octopus': 100,             # g par portion

            # Légumes
            'onion': 150,               # g par oignon moyen
            'garlic': 5,                # g par gousse
            'garlic clove': 5,          # g par gousse
            'carrot': 120,              # g par carotte
            'potato': 150,              # g par pomme de terre
            'tomato': 150,              # g par tomate
            'mushroom': 15,             # g par champignon
            'bell pepper': 120,         # g par poivron
            'yellow pepper': 120,        # g par poivron
            'red pepper': 120,          # g par poivron
            'lettuce': 50,              # g par portion
            'courgette': 200,           # g par courgette
            'zucchini': 200,            # g par courgette
            'aubergine': 250,           # g par aubergine
            'spring onion': 15,         # g par oignon vert
            'scallion': 15,             # g par oignon vert
            'celery': 40,               # g par branche
            'fennel': 200,              # g par bulbe
            'bean sprouts': 50,         # g par portion
            'peas': 80,                 # g par portion
            'green beans': 100,         # g par portion
            'chinese broccoli': 100,    # g par portion
            'broccolini': 100,          # g par portion
            'cabbage': 150,             # g par portion
            'napa cabbage': 150,        # g par portion
            'bok choy': 100,            # g par portion
            'bamboo shoot': 100,        # g par portion
            'asparagus': 100,           # g par portion
            'spinach': 150,             # g par portion
            'broccoli': 200,            # g par tête

            # Fromages et Produits Laitiers
            'cheese': 30,               # g par tranche
            'cheddar cheese': 30,       # g par tranche
            'mozzarella': 125,          # g par boule
            'parmesan': 25,             # g par portion
            'feta': 50,                 # g par portion
            'ricotta cheese': 450,      # g par livre
            'mascarpone': 450,          # g par livre
            'cream cheese': 225,        # g (8 onces)
            'goat cheese': 280,         # g (10 onces)
            'cream': 240,               # ml par tasse
            'double cream': 240,        # ml par tasse
            'heavy cream': 240,         # ml par tasse
            'greek yogurt': 170,        # g par portion
            'full fat yogurt': 170,     # g par portion
            'coconut milk': 400,        # ml par boîte

            # Céréales, Pâtes et Pains
            'rice': 75,                 # g cru par portion
            'basmati rice': 75,         # g cru par portion
            'sushi rice': 75,           # g cru par portion
            'arborio rice': 75,         # g cru par portion
            'pasta': 85,                # g cru par portion
            'rice noodles': 85,         # g cru par portion
            'macaroni': 85,             # g cru par portion
            'lasagne sheets': 50,       # g par feuille
            'noodles': 85,              # g cru par portion
            'udon noodles': 85,         # g cru par portion
            'flour': 120,               # g par tasse
            'bread': 30,                # g par tranche
            'pita bread': 60,           # g par pain
            'burger bun': 60,           # g par pain
            'breadcrumbs': 30,          # g par portion
            'couscous': 75,             # g cru par portion

            # Herbes et Épices
            'basil': 5,                 # g par portion
            'parsley': 5,               # g par portion
            'thyme': 2,                 # g par branche
            'rosemary': 2,              # g par branche
            'oregano': 2,               # g par cuillère à soupe
            'ginger': 15,               # g par morceau
            'lemongrass': 15,           # g par tige
            'coriander': 5,             # g par portion
            'cilantro': 5,              # g par portion
            'mint': 5,                  # g par portion
            'kaffir lime leaves': 2,    # g par feuille
            'bay leaf': 1,              # g par feuille
            'curry paste': 15,          # g par cuillère à soupe

            # Sauces et Condiments
            'soy sauce': 15,            # ml par cuillère à soupe
            'fish sauce': 15,           # ml par cuillère à soupe
            'oyster sauce': 15,         # ml par cuillère à soupe
            'tomato sauce': 240,        # ml par tasse
            'tomato puree': 15,         # g par cuillère à soupe
            'hot sauce': 15,            # ml par cuillère à soupe
            'mustard': 15,              # g par cuillère à soupe
            'mayonnaise': 14,           # g par cuillère à soupe

            # Huiles et Matières Grasses
            'butter': 14,               # g par cuillère à soupe
            'vegan butter': 14,         # g par cuillère à soupe
            'ghee': 15,                 # g par cuillère à soupe
            'olive oil': 15,            # ml par cuillère à soupe
            'vegetable oil': 15,        # ml par cuillère à soupe
            'sesame oil': 15,           # ml par cuillère à soupe
            'oil': 15,                  # ml par cuillère à soupe

            # Fruits et Fruits Secs
            'pineapple': 150,           # g par portion
            'peaches': 150,             # g par fruit
            'pears': 150,               # g par fruit
            'apples': 150,              # g par fruit
            'plantain': 150,            # g par fruit
            'raisins': 30,              # g par portion

            # Noix et Graines
            'peanuts': 30,              # g par portion
            'cashews': 30,              # g par portion
            'walnuts': 30,              # g par portion
            'almonds': 30,              # g par portion
            'pine nuts': 30,            # g par portion

            # Autres Ingrédients
            'eggs': 50,                 # g par œuf
            'egg whites': 30,           # g par blanc
            'egg yolks': 20,            # g par jaune
            'tofu': 100,                # g par portion
            'sugar': 15,                # g par cuillère à soupe
            'brown sugar': 15,          # g par cuillère à soupe
            'honey': 21,                # g par cuillère à soupe
            'vinegar': 15,              # ml par cuillère à soupe
        }

        
        # Conversions de base
        self.conversions = {
            # Volumes
            'cup': 240,              # ml
            'cups': 240,             # ml
            'tsp': 5,                # ml (cuillère à café)
            'teaspoon': 5,           # ml
            'tbsp': 15,              # ml (cuillère à soupe)
            'tablespoon': 15,        # ml
            'tbs': 15,               # ml
            'fluid oz': 30,          # ml
            'fl oz': 30,             # ml
            'pint': 473,             # ml
            'quart': 946,            # ml
            'gallon': 3785,          # ml
            'ml': 1,                 # ml
            'l': 1000,               # ml
            
            # Poids
            'oz': 28.35,             # g
            'ounce': 28.35,          # g
            'lb': 453.6,             # g
            'pound': 453.6,          # g
            'kg': 1000,              # g
            'g': 1,                  # g
            
            # Portions spécifiques
            'slice': 30,             # g (pour pain, fromage)
            'piece': 1,              # unité
            'clove': 5,              # g (pour l'ail)
            'sprig': 2,              # g (pour herbes fraîches)
            'bunch': 30,             # g (pour herbes)
            'dash': 0.5,             # ml/g
            'pinch': 0.25,           # ml/g
            'handful': 30,           # g
            'large': 1.5,            # multiplicateur
            'small': 0.75,           # multiplicateur
            'medium': 1,             # multiplicateur
        }
        
        # Chemins des fichiers
        self.chemin_base = "/Users/ludovicveltz/Documents/Bootcamp_GENAI_2025/Crashcourse/hackaton_projet_W3D5/DATASET"
        self.chemin_fichier = os.path.join(self.chemin_base, "plats_populaires_ingredients.csv")
        self.chemin_sortie = os.path.join(self.chemin_base, "plats_populaires_nutriments_complet.csv")


    def extraire_ingredients_et_quantites(self, ingredients_str: str) -> List[Tuple[str, float, str]]:
        """Extrait les ingrédients avec leurs quantités et unités"""
        if pd.isna(ingredients_str) or ingredients_str == 'Non disponible':
            return []
        
        ingredients_list = []
        for ing in ingredients_str.split('|'):
            ing = ing.strip()
            if '(' in ing and ')' in ing:
                try:
                    nom = ing.split('(')[0].strip()
                    quantite_str = ing.split('(')[1].split(')')[0].strip()
                    qte, unite = self.normaliser_quantite(quantite_str, nom)
                    ingredients_list.append((nom, qte, unite))
                except Exception as e:
                    print(f"Erreur lors du traitement de l'ingrédient {ing}: {e}")
                    continue
            else:
                for ing_key, portion in self.portions_standard.items():
                    if ing_key in ing.lower():
                        ingredients_list.append((ing, portion, 'g'))
                        break
                else:
                    ingredients_list.append((ing, 1, 'portion'))
        return ingredients_list

    def normaliser_quantite(self, quantite_str: str, ingredient: str) -> Tuple[float, str]:
        """Normalise les quantités en unités standard"""
        # Gestion des cas spéciaux et descriptions
        special_cases = {
            'dash': 0.5,
            'pinch': 0.25,
            'chopped': 5.0,
            'garnish': 5.0,
            'to serve': 5.0,
            'to taste': 1.0,
            'leaves': 2.0
        }
        
        # Si la chaîne est vide ou contient un cas spécial
        if not quantite_str or any(case in quantite_str.lower() for case in special_cases):
            for case, value in special_cases.items():
                if case in str(quantite_str).lower():
                    return value, 'g'
            
            # Portions standard par défaut selon l'ingrédient
            for ing_key, portion in self.portions_standard.items():
                if ing_key in ingredient.lower():
                    return portion, 'g'
            return 5.0, 'g'

        quantite_str = quantite_str.lower().strip()

        # Définition des unités préférées par type d'ingrédient
        ingredient_units = {
            'oil': 'ml',
            'stock': 'ml',
            'vinegar': 'ml',
            'sauce': 'ml',
            'milk': 'ml',
            'cream': 'ml',
            'juice': 'ml',
            'water': 'ml',
            'wine': 'ml',
            'default': 'g'
        }

        # Limites maximales par type d'ingrédient
        limites = {
            'beef': 500,       # g
            'chicken': 300,    # g
            'fish': 300,      # g
            'garlic': 30,      # g
            'onion': 300,      # g
            'cheese': 200,     # g
            'salt': 10,        # g
            'pepper': 5,       # g
            'spice': 10,       # g pour les épices
            'oil': 100,        # ml
            'milk': 500,       # ml
            'flour': 300,      # g
            'sugar': 200,      # g
            'butter': 100,     # g
            'stock': 500,      # ml
            'sauce': 100,      # ml
            'vegetable': 300,  # g
            'default': 300     # g/ml
        }

        try:
            # Extraction et conversion du nombre
            if '/' in quantite_str:
                parts = quantite_str.split()
                nombre = 0
                for part in parts:
                    if '/' in part:
                        num, denom = map(float, part.split('/'))
                        nombre += num / denom
                    elif part.replace('.', '').isdigit():
                        nombre += float(part)
            else:
                nombre = float(''.join([c for c in quantite_str.split()[0] if c.isdigit() or c == '.']))

            # Détermination de l'unité préférée
            unite_preferee = 'g'
            for ing_type, unite in ingredient_units.items():
                if ing_type in ingredient.lower():
                    unite_preferee = unite
                    break

            # Application des limites et conversion
            for ing_type, limite in limites.items():
                if ing_type in ingredient.lower():
                    if nombre > limite:
                        print(f"Ajustement quantité pour {ingredient}: {nombre} -> {limite}")
                        nombre = limite
                    break

            # Conversion selon l'unité trouvée dans la chaîne
            for unite, conversion in self.conversions.items():
                if unite in quantite_str:
                    if unite in ['cup', 'cups', 'tsp', 'tbsp', 'tbs', 'fluid oz', 'fl oz', 'pint', 'quart', 'gallon', 'ml', 'l']:
                        return nombre * conversion, unite_preferee
                    return nombre * conversion, unite_preferee

            # Si pas d'unité trouvée, utiliser l'unité préférée
            return nombre, unite_preferee

        except Exception as e:
            print(f"Erreur de conversion pour {quantite_str}: {e}")
            # Valeur par défaut selon le type d'ingrédient
            for ing_type, limite in limites.items():
                if ing_type in ingredient.lower():
                    return limite/2, ingredient_units.get(ing_type, 'g')
            return 5.0, 'g'


    def rechercher_nutriments(self, ingredient: str, quantite: float, unite: str) -> Dict:
        """Recherche les nutriments pour un ingrédient donné via l'API USDA"""
        params = {
            'api_key': self.API_KEY,
            'query': ingredient,
            'pageSize': 1,
            'dataType': ['Foundation', 'Survey (FNDDS)']
        }
        
        try:
            response = requests.get(self.base_url, params=params)
            if response.status_code == 200:
                data = response.json()
                if data.get('foods'):
                    nutrients = data['foods'][0]['foodNutrients']
                    nutriments = {}
                    
                    # Créer un dictionnaire avec nutrientName comme clé
                    nutrients_dict = {}
                    for nutrient in nutrients:
                        nutrient_name = nutrient.get('nutrientName')
                        if nutrient_name:
                            nutrients_dict[nutrient_name] = nutrient
                    
                    # Parcourir les nutriments cibles
                    for api_name, fr_name in self.nutriments_cibles.items():
                        if api_name in nutrients_dict:
                            valeur = nutrients_dict[api_name].get('value', 0)
                            # Conversion selon l'unité et la quantité
                            if unite in ['g', 'ml']:
                                valeur = (valeur * quantite) / 100  # Car les valeurs USDA sont pour 100g
                            else:
                                valeur = valeur * quantite
                            nutriments[fr_name] = round(valeur, 2)  # Arrondir à 2 décimales
                        else:
                            nutriments[fr_name] = 0
                    
                    return nutriments
            
            # Si pas de résultat, retourner des zéros
            return {fr_name: 0 for api_name, fr_name in self.nutriments_cibles.items()}
        
        except Exception as e:
            print(f"Erreur pour {ingredient}: {e}")
            return {fr_name: 0 for api_name, fr_name in self.nutriments_cibles.items()}

    def analyser_plats(self):
        try:
            df = pd.read_csv(self.chemin_fichier, sep=',')
            print(f"Dataset chargé avec succès : {len(df)} plats")
            
            resultats = []
            total_plats = len(df)
            
            for index, row in df.iterrows():
                plat = row['Plat'].strip()
                print(f"\nAnalyse du plat {index + 1}/{total_plats} : {plat}")
                
                ingredients = self.extraire_ingredients_et_quantites(row['Ingrédients'])
                nutriments_totaux = {fr_name: 0 for api_name, fr_name in self.nutriments_cibles.items()}
                
                for ingredient, quantite, unite in ingredients:
                    print(f"  Analyse de : {ingredient} ({quantite} {unite})")
                    nutriments = self.rechercher_nutriments(ingredient, quantite, unite)
                    
                    # Additionner les nutriments
                    for nom_fr, valeur in nutriments.items():
                        nutriments_totaux[nom_fr] += valeur
                
                # Créer l'entrée pour ce plat
                resultat = {
                    'Plat': plat,
                    'Pays': row['Pays'].strip(),
                    'Catégorie': row['Catégorie'].strip(),
                    **nutriments_totaux  # Déployer les nutriments calculés
                }
                resultats.append(resultat)
                
                # Sauvegarde temporaire
                if (index + 1) % 5 == 0:
                    df_temp = pd.DataFrame(resultats)
                    df_temp.to_csv(os.path.join(self.chemin_base, "temp_results.csv"),
                                index=False, encoding='utf-8-sig')
                    print(f"Sauvegarde temporaire effectuée après {index + 1} plats")
            
            # Sauvegarde finale
            df_final = pd.DataFrame(resultats)
            print("\nAperçu des résultats avant sauvegarde:")
            print(df_final.head())
            
            df_final.to_csv(self.chemin_sortie, index=False, encoding='utf-8-sig')
            print("\nAnalyse terminée avec succès!")
            return df_final
            
        except Exception as e:
            print(f"Erreur lors de l'analyse : {e}")
            return None

if __name__ == "__main__":
    print("=== ANALYSE NUTRITIONNELLE DES PLATS TRADITIONNELS ===")
    analyzer = NutrientAnalyzer()
    df_resultat = analyzer.analyser_plats()
# Out:
# === ANALYSE NUTRITIONNELLE DES PLATS TRADITIONNELS ===
# Dataset chargé avec succès : 83 plats
#
# Analyse du plat 1/83 : Couscous
#   Analyse de : 1 3/4 cups vegetable broth (1 portion)
#   Analyse de : 3/4 cup uncooked couscous (75 g)
#
# Analyse du plat 2/83 : Pizza
#   Analyse de : 4 c. self-rising flour (120 g)
#   Analyse de : 1/4 c. sugar (15 g)
#   Analyse de : 2 c. warm milk (1 portion)
#   Analyse de : 1/3 c. oil (15 g)
#
# Analyse du plat 3/83 : Steak-frites
#   Analyse de : 4 beef steaks, such as porterhouse, sirloin, rib eye, shell or filet mignon (1020.6 g)
#   Analyse de : 5 tablespoons unsalted butter (14 g)
#   Analyse de : salt and freshly ground black pepper to taste (1 portion)
#   Analyse de : 1 tablespoon water (1 portion)
#   Analyse de : Belgian fries (1 portion)
#
# Analyse du plat 4/83 : Blanquette de veau
# Erreur de conversion pour bay leaf, thyme branch, 10 sprigs flat-leaf parsley: could not convert string to float: ''
#   Analyse de : 2 1/2 lbs veal shoulder, in 2-inch cubes (300 g)
#   Analyse de : 2 quarts veal or 2 quarts chicken broth, warm (150 g)
#   Analyse de : 1 large carrot, peeled, in 3-inch chunks (120 g)
#   Analyse de : 3 leeks, cleaned, trimmed to 4 inches with two outer layers removed (1 portion)
#   Analyse de : 1 stalk celery, in 2-inch pieces (40 g)
#   Analyse de : 1 bouquet garni (5.0 g)
#   Analyse de : salt (1 portion)
#   Analyse de : 18 medium white mushrooms, trimmed (15 g)
#   Analyse de : 1 (283.5 g)
#   Analyse de : 1 cup heavy cream (240 g)
#   Analyse de : 2 large egg yolks (20 g)
#   Analyse de : 1 1/2 tablespoons lemon juice (1 portion)
#   Analyse de : fresh ground white pepper (1 portion)
#   Analyse de : flat leaf parsley (5.0 g)
#   Analyse de : 1 1/2 cups basmati rice or 1 1/2 cups jasmine rice, steamed (75 g)
#
# Analyse du plat 5/83 : Boeuf bourguignon
#   Analyse de : 3 lb. lean beef, cubed (200 g)
#   Analyse de : 3 Tbsp. olive oil (15 g)
#   Analyse de : 1 c. Burgundy (1 portion)
#   Analyse de : 1 bay leaf (1 g)
#   Analyse de : 1/2 tsp. thyme (2 g)
#   Analyse de : 1 clove garlic, minced (5 g)
#   Analyse de : 1/2 tsp. salt (1 portion)
#   Analyse de : 2 Tbsp. tomato paste (150 g)
#   Analyse de : 2 c. beef broth (200 g)
#   Analyse de : 2 Tbsp. flour (120 g)
#   Analyse de : 4 Tbsp. butter (14 g)
#   Analyse de : 1 lb. mushrooms, sliced (15 g)
#   Analyse de : 2 Tbsp. vegetable oil (15 g)
#   Analyse de : 1 (453.6 g)
#   Analyse de : cooked rice (75 g)
# Sauvegarde temporaire effectuée après 5 plats
#
# Analyse du plat 6/83 : Ratatouille
# Erreur de conversion pour optional: could not convert string to float: ''
#   Analyse de : 1 1/2 Tbsp. olive oil (15 g)
#   Analyse de : 2 cloves garlic, minced (5 g)
#   Analyse de : 2 medium onion, thinly sliced (150 g)
#   Analyse de : 3/4 lb. eggplant, peeled and diced (1 portion)
#   Analyse de : 1/2 lb. zucchini, unpeeled and sliced (200 g)
#   Analyse de : 1 sweet green pepper, sliced into rings (1 portion)
#   Analyse de : 2 tsp. Italian seasoning (1 portion)
#   Analyse de : 1 tsp. sugar (15 g)
#   Analyse de : salt (5.0 g)
#   Analyse de : pepper to taste (1 portion)
#   Analyse de : 4 medium fresh or canned tomatoes, peeled and sliced (150 g)
#
# Analyse du plat 7/83 : Cassoulet
#   Analyse de : 1 lb. ground beef (200 g)
#   Analyse de : 1 c. sliced celery (40 g)
#   Analyse de : 1/2 c. chopped onion (150 g)
#   Analyse de : 1/2 c. chopped green pepper (1 portion)
#   Analyse de : 1 clove garlic, crushed (5 g)
#   Analyse de : 1 tsp. salt (1 portion)
#   Analyse de : 1 (1000.0 g)
#   Analyse de : 1 (1000.0 g)
#   Analyse de : 1 (1000.0 g)
#   Analyse de : 1 (170.10000000000002 g)
#
# Analyse du plat 8/83 : Quiche Lorraine
# Erreur de conversion pour i use pet ritz deep dish pie shell: could not convert string to float: ''
# Erreur de conversion pour whipping cream: could not convert string to float: ''
#   Analyse de : 2 c. grated Swiss cheese (30 g)
#   Analyse de : 8 slices crisp bacon, crumbled (30 g)
#   Analyse de : 1 unbaked 9-inch pie crust (5.0 g)
#   Analyse de : 4 large eggs (50 g)
#   Analyse de : 1/4 tsp. pepper (1 portion)
#   Analyse de : 1/2 tsp. powdered mustard (15 g)
#   Analyse de : 2 c. heavy cream (5.0 g)
#   Analyse de : 1/2 scant tsp. salt (1 portion)
#   Analyse de : dash of cayenne pepper (1 portion)
#   Analyse de : 1/4 or less chopped onion (150 g)
#
# Analyse du plat 9/83 : Croque-monsieur
#   Analyse de : 1 tablespoon Dijon mustard (15 g)
#   Analyse de : 2 tablespoons mayonnaise (14 g)
#   Analyse de : 4 tablespoons butter or margarine, softened (14 g)
#   Analyse de : 6 slices white bread (30 g)
#   Analyse de : 6 slices Swiss cheese (30 g)
#   Analyse de : 12 slices thinly sliced deli ham (1 portion)
#   Analyse de : 4 tablespoons all-purpose flour (120 g)
#   Analyse de : 1/2 teaspoon baking powder (1 portion)
#   Analyse de : 1/4 teaspoon salt (1 portion)
#   Analyse de : 2 eggs (50 g)
#   Analyse de : 1/4 cup water (1 portion)
#   Analyse de : 1 tablespoon vegetable oil (15 g)
#
# Analyse du plat 10/83 : Sushi
# Erreur de conversion pour see following: could not convert string to float: ''
#   Analyse de : 1 c. water (1 portion)
#   Analyse de : 3 Tbsp. white vinegar (15 g)
#   Analyse de : 2 Tbsp. sugar (15 g)
#   Analyse de : 3/4 c. short-grain rice (75 g)
#   Analyse de : 6 Nori seaweed squares (1 portion)
#   Analyse de : soy sauce (15 g)
#   Analyse de : wasabi (1 portion)
#   Analyse de : filling of choice (5.0 g)
# Sauvegarde temporaire effectuée après 10 plats
#
# Analyse du plat 11/83 : Ramen
#   Analyse de : 2 tablespoons sesame oil (15 g)
#   Analyse de : 4 green onions, finely chopped (150 g)
#   Analyse de : 2 tablespoons fresh ginger, finely chopped (15 g)
#   Analyse de : 4 cloves of garlic, finely chopped (5 g)
#   Analyse de : 2 tablespoons chili garlic sauce (5 g)
#   Analyse de : 2 tablespoons soy sauce (15 g)
#   Analyse de : 3 cups chicken stock (150 g)
#   Analyse de : 2 teaspoons rice wine vinegar (75 g)
#   Analyse de : 2 teaspoons fish sauce (15 g)
#   Analyse de : 2 eggs (50 g)
#   Analyse de : 5 ounces Japanese curly noodles (85 g)
#
# Analyse du plat 12/83 : Tempura
#   Analyse de : 2 Tbsp. cold water (1 portion)
#   Analyse de : 2 Tbsp. whole wheat flour (120 g)
#   Analyse de : 1/2 Tbsp. beaten egg (1 portion)
#   Analyse de : salt (1 portion)
#   Analyse de : oil for frying (15 g)
#   Analyse de : pre-cut vegetables (1 portion)
#
# Analyse du plat 13/83 : Tonkatsu
# Erreur de conversion pour white: could not convert string to float: ''
#   Analyse de : 4 pieces pork cutlet (200 g)
#   Analyse de : 1 spoon sugar (15 g)
#   Analyse de : bread powder (30 g)
#   Analyse de : tonkatsu sauce (1 portion)
#   Analyse de : dressing (1 portion)
#   Analyse de : 2 tsp. soy sauce (15 g)
#   Analyse de : 1 egg (1 portion)
#   Analyse de : vegetable oil (15 g)
#   Analyse de : cabbage (150 g)
#   Analyse de : rice (5.0 g)
#
# Analyse du plat 14/83 : Gyoza
# Erreur de conversion pour one bowl: could not convert string to float: ''
#   Analyse de : 1 lb. ground beef (200 g)
#   Analyse de : 1 egg (1 portion)
#   Analyse de : 1/2 to 3/4 c. cabbage, finely chopped (150 g)
#   Analyse de : 1/2 c. green onion, finely chopped (150 g)
#   Analyse de : salt and pepper to taste (1 portion)
#   Analyse de : 1 pkg. wonton wraps (1 portion)
#   Analyse de : water (5.0 g)
#   Analyse de : oil (15 g)
#
# Analyse du plat 15/83 : Okonomiyaki
#   Analyse de : 1 cup chopped cooked chicken (150 g)
#   Analyse de : 1 1/2 cups thinly sliced napa cabbage (150 g)
#   Analyse de : 1/4 cup shredded carrots (120 g)
#   Analyse de : 3 green onions, chopped (150 g)
#   Analyse de : 12 fresh green beans, cut into 1/2 inch pieces (100 g)
#   Analyse de : 1 small green bell pepper, cut into thin strips (120 g)
#   Analyse de : 1 small zucchini, cut into thin strips (200 g)
#   Analyse de : 3 eggs, lightly beaten (50 g)
#   Analyse de : 3/4 cup all-purpose flour (120 g)
#   Analyse de : 3/4 cup chicken stock (150 g)
#   Analyse de : 2 teaspoons soy sauce (15 g)
#   Analyse de : 1 teaspoon vegetable oil (15 g)
#   Analyse de : 1/4 teaspoon toasted sesame oil (15 g)
# Sauvegarde temporaire effectuée après 15 plats
#
# Analyse du plat 16/83 : Miso soup
#   Analyse de : 1/2 c. dried shrimp (100 g)
#   Analyse de : 5 c. water (1 portion)
#   Analyse de : 3/4 c. miso (1 portion)
#   Analyse de : 1/2 cube tofu (100 g)
#   Analyse de : 3/8 c. green onion (150 g)
#   Analyse de : Saimin noodles, optional (85 g)
#
# Analyse du plat 17/83 : Takoyaki
# Erreur de conversion pour the more sustainable choice: could not convert string to float: ''
# Erreur de conversion pour mine makes 14 at a time: could not convert string to float: ''
#   Analyse de : 3/4 cup brown rice flour (75 g)
#   Analyse de : 3/4 cup sweet rice flour (75 g)
#   Analyse de : 1/2 cup tapioca flour (120 g)
#   Analyse de : 2 1/2 cups dashi broth (0.5 g)
#   Analyse de : 2 eggs (50 g)
#   Analyse de : 1/2 pound boiled octopus or calamari (50.0 ml)
#   Analyse de : 1/2 cup chopped scallions (15 g)
#   Analyse de : 1/4 cup chopped seaweed (1 portion)
#   Analyse de : roasted seaweed for topping (1 portion)
#   Analyse de : mayo &amp; worcestershire mix for dipping (1 portion)
#   Analyse de : takoyaki pan (5.0 g)
#
# Analyse du plat 18/83 : Teriyaki
#   Analyse de : 2 lb. flank steak (1 portion)
#   Analyse de : 1/2 cup soy sauce (15 g)
#   Analyse de : 1/4 cup oil (15 g)
#   Analyse de : 2 tsp. garlic powder (5 g)
#   Analyse de : 2 Tbsp. honey (21 g)
#   Analyse de : 2 Tbsp. vinegar (15 g)
#   Analyse de : 2 tsp. ginger powder (15 g)
#
# Analyse du plat 19/83 : Pizza Margherita
# Erreur de conversion pour recipe follows: could not convert string to float: ''
#   Analyse de : 1 Tbsp. olive oil (15 g)
#   Analyse de : 1/2 c. tomato sauce (50.0 ml)
#   Analyse de : 2 oz. Mozzarella cheese, sliced 1/8-inch thick (30 g)
#   Analyse de : freshly ground pepper to taste (1 portion)
#   Analyse de : 1/2 c. loosely packed fresh basil leaves (5 g)
#   Analyse de : 1/4 c. freshly grated Parmesan cheese (30 g)
#
# Analyse du plat 20/83 : Pasta Carbonara
#   Analyse de : 1 lb. bacon (30 g)
#   Analyse de : 1 c. mushrooms, sliced (15 g)
#   Analyse de : 1 clove garlic (5 g)
#   Analyse de : 1 green pepper, cubed (1 portion)
#   Analyse de : 2 eggs (50 g)
#   Analyse de : 1/2 c. grated cheese (30 g)
#   Analyse de : 2 Tbsp. fresh parsley (5 g)
#   Analyse de : 1 lb. spaghetti (1 portion)
# Sauvegarde temporaire effectuée après 20 plats
#
# Analyse du plat 21/83 : Lasagna
#   Analyse de : 1/2 lb. Italian sausage (1 portion)
#   Analyse de : 1 lb. ground round (1 portion)
#   Analyse de : 1/2 large onion (150 g)
#   Analyse de : 1/2 green pepper (1 portion)
#   Analyse de : 1/4 c. celery (40 g)
#   Analyse de : 1/2 tsp. oregano (2 g)
#   Analyse de : 1/4 tsp. garlic (5 g)
#   Analyse de : salt and pepper to taste (1 portion)
#   Analyse de : 1 large can tomatoes (150 g)
#   Analyse de : 1 jar Ragu (1 portion)
#   Analyse de : 1 large can tomato paste (150 g)
#   Analyse de : 1 lb. Mozzarella cheese (30 g)
#   Analyse de : 1 pkg. Parmesan cheese (30 g)
#   Analyse de : 1 container Ricotta cheese (30 g)
#   Analyse de : 10 lasagna noodles (85 g)
#
# Analyse du plat 22/83 : Risotto
#   Analyse de : 3 c. low salt chicken broth (150 g)
#   Analyse de : 1 medium onion, chopped (150 g)
#   Analyse de : 6 Tbsp. extra virgin flavorful olive oil (15 g)
#   Analyse de : 1 1/3 c. raw Italian Arborio rice (75 g)
#   Analyse de : 1/3 c. grated Parmesan cheese (30 g)
#   Analyse de : 1/4 tsp. black pepper (1 portion)
#
# Analyse du plat 23/83 : Osso Buco
# Erreur de conversion pour flat: could not convert string to float: ''
#   Analyse de : 3 to 4 lb. veal shanks or shins, 2 inches thick (300 g)
#   Analyse de : 1/3 c. flour (120 g)
#   Analyse de : white pepper (1 portion)
#   Analyse de : 3 large cloves garlic, minced (5 g)
#   Analyse de : 4 carrots, sliced (120 g)
#   Analyse de : 2 ribs celery, chopped (40 g)
#   Analyse de : 1 large onion, minced (150 g)
#   Analyse de : 1/2 tsp. dried thyme, crushed (2 g)
#   Analyse de : 1/4 c. olive oil (15 g)
#   Analyse de : 1/4 c. butter or margarine (14 g)
#   Analyse de : 1 tsp. dried rosemary, crushed (2 g)
#   Analyse de : 1 c. Marsala wine (1 portion)
#   Analyse de : 1 c. chicken broth (150 g)
#   Analyse de : 1 (226.8 g)
#   Analyse de : 2 Tbsp. chopped Italian (5.0 g)
#   Analyse de : 1 Tbsp. grated lemon rind (1 portion)
#
# Analyse du plat 24/83 : Tiramisu
#   Analyse de : 8 oz. bittersweet chocolate (1 portion)
#   Analyse de : 24 ladyfingers (1 portion)
#   Analyse de : 2 c. strong Espresso coffee, cooled (1 portion)
#   Analyse de : 6 eggs, separated (50 g)
#   Analyse de : 6 heaping Tbsp. granulated sugar (15 g)
#   Analyse de : 1 lb. Mascarpone (450 g)
#
# Analyse du plat 25/83 : Gnocchi
#   Analyse de : 1 lb. Ricotta cheese (30 g)
#   Analyse de : 2 c. flour (120 g)
#   Analyse de : 1 egg (1 portion)
# Sauvegarde temporaire effectuée après 25 plats
#
# Analyse du plat 26/83 : Pesto alla Genovese
#   Analyse de : 1 bunch fresh basil, washed and thoroughly dried (2.0 g)
#   Analyse de : 2 garlic cloves, peeled (5 g)
#   Analyse de : 1 pinch salt (1 portion)
#   Analyse de : 2 tablespoons pine nuts, toasted (30 g)
#   Analyse de : 3 tablespoons freshly grated parmigiano-reggiano cheese (30 g)
#   Analyse de : 3 tablespoons freshly grated pecorino cheese (30 g)
#   Analyse de : 1 cup extra virgin olive oil (15 g)
#
# Analyse du plat 27/83 : Pasta all'Arrabbiata
# Erreur de conversion pour or anyother pasta: could not convert string to float: ''
#   Analyse de : 4 fresh chilies (1 portion)
#   Analyse de : 4 garlic cloves (5 g)
#   Analyse de : 1 kg canned whole tomato (150 g)
#   Analyse de : 1/2 cup white wine (1 portion)
#   Analyse de : 1 1/4 kg penne rigate (5.0 g)
#   Analyse de : bunch chopped parsley (5 g)
#
# Analyse du plat 28/83 : Vitello Tonnato
#   Analyse de : 2 oz canned anchovy fillets, drained, 4 fillets cut into 1/3 inch pieces (1 portion)
#   Analyse de : 1 clove garlic, thinly sliced (5 g)
#   Analyse de : 3 1/3 lb veal loin, shallow cuts made along length of veal (300 g)
#   Analyse de : 2 None carrots, finely chopped (120 g)
#   Analyse de : 3 stalks celery, trimmed, finely chopped (40 g)
#   Analyse de : 2 None Spanish onions, quartered (150 g)
#   Analyse de : 6 sprigs fresh parsley (5 g)
#   Analyse de : 5 cups chicken stock (150 g)
#   Analyse de : 1 2/3 cups dry white wine (1 portion)
#   Analyse de : 3/4 cup vegetable oil (15 g)
#   Analyse de : 1 None egg yolk (1 portion)
#   Analyse de : 3.5 oz canned tuna, drained (1 portion)
#   Analyse de : 2 tbsp lemon juice (1 portion)
#   Analyse de : 1/4 cup heavy cream (240 g)
#   Analyse de : None None capers, to serve (1 portion)
#
# Analyse du plat 29/83 : Mapo Tofu
# Erreur de conversion pour optional: could not convert string to float: ''
# Erreur de conversion pour preferably firm or extra-firm: could not convert string to float: ''
#   Analyse de : 1 garlic clove, minced (5 g)
#   Analyse de : 1/4 lb ground pork (5.0 g)
#   Analyse de : 2 tablespoons spicy bean paste (1 portion)
#   Analyse de : 2 teaspoons chili powder (1 portion)
#   Analyse de : 2 teaspoons light soy sauce (15 g)
#   Analyse de : 12 1/3 ounces silken tofu (5.0 g)
#   Analyse de : 2 tablespoons vegetable oil (15 g)
#   Analyse de : 1 tablespoon chili oil (15 g)
#   Analyse de : 1 tablespoon black bean garlic sauce (5 g)
#   Analyse de : 1 leek, ends trimmed, sliced and rinsed (1 portion)
#   Analyse de : 1/2 cup low sodium chicken broth or 1/2 cup vegetable broth (150 g)
#   Analyse de : 1 1/2 teaspoons cornstarch (1 portion)
#   Analyse de : 1 1/2 - 2 tablespoons szechuan peppercorns, ground (1 portion)
#
# Analyse du plat 30/83 : Tacos al Pastor
#   Analyse de : 8 dried pasilla chiles, seeded and torn to pieces (1 portion)
#   Analyse de : 8 dried guajillo chiles, seeded and torn to pieces (1 portion)
#   Analyse de : 8 cloves garlic, chopped (5 g)
#   Analyse de : 1 teaspoon achiote powder (1 portion)
#   Analyse de : 1/2 teaspoon ground cumin (1 portion)
#   Analyse de : 5 whole cloves (1 portion)
#   Analyse de : 1 cup white vinegar (15 g)
#   Analyse de : salt to taste (1 portion)
#   Analyse de : 2 pounds pork tenderloin, thinly sliced (200 g)
#   Analyse de : 1/2 cup chopped pineapple (150 g)
#   Analyse de : 32 (5.0 g)
#   Analyse de : 1 small onion, chopped (150 g)
#   Analyse de : 1/2 cup chopped fresh cilantro (5 g)
#   Analyse de : 4 limes, cut in wedges (1 portion)
# Sauvegarde temporaire effectuée après 30 plats
#
# Analyse du plat 31/83 : Guacamole
#   Analyse de : 1 large avocado (1 portion)
#   Analyse de : 1/2 lemon (1 portion)
#   Analyse de : 2 tsp. grated onion (150 g)
#   Analyse de : 3 to 4 drops Tabasco sauce (1 portion)
#   Analyse de : garlic salt (5 g)
#   Analyse de : Fritos or any corn chips (1 portion)
#
# Analyse du plat 32/83 : Enchiladas
#   Analyse de : 1 (340.20000000000005 g)
#   Analyse de : 1 qt. water (1 portion)
#   Analyse de : 2 cloves garlic, minced (5 g)
#   Analyse de : 5 tsp. chili powder (1 portion)
#   Analyse de : 1 lb. lean ground beef (200 g)
#   Analyse de : 1/2 c. chopped green onions (150 g)
#   Analyse de : 2 c. shredded Monterey Jack cheese (30 g)
#   Analyse de : 1 doz. corn tortillas (1 portion)
#
# Analyse du plat 33/83 : Mole Poblano
# Erreur de conversion pour more chicken may be used: could not convert string to float: ''
#   Analyse de : 2 cut-up chickens, boiled (150.0 g)
#   Analyse de : 1 (226.8 g)
#   Analyse de : 6 California chilies (1 portion)
#   Analyse de : 1 (113.4 g)
#   Analyse de : 1 (141.75 g)
#   Analyse de : 1/2 c. dry peeled peanuts (30 g)
#   Analyse de : 1 tomato (150 g)
#   Analyse de : 1 medium onion, thinly sliced (150 g)
#   Analyse de : 3/4 c. oil (15 g)
#   Analyse de : 1 tsp. sugar (15 g)
#   Analyse de : 1/2 c. dry peeled pumpkin seeds (1 portion)
#   Analyse de : 1 tsp. cinnamon (1 portion)
#   Analyse de : 1 tsp. ground cumin seed (1 portion)
#   Analyse de : 1/2 tsp. pepper (1 portion)
#   Analyse de : 3 cloves garlic (5 g)
#   Analyse de : 3 laurel leaves (1 portion)
#   Analyse de : 1/2 bar Ibarra chocolate (1 portion)
#   Analyse de : 2 bananas (1 portion)
#   Analyse de : 1 loaf French bread, cut in 8 thick slices (30 g)
#
# Analyse du plat 34/83 : Chiles en Nogada
#   Analyse de : Stuffing (1 portion)
#   Analyse de : 1 cup olive oil (15 g)
#   Analyse de : 2 large white onions, grated (150 g)
#   Analyse de : 12 garlic cloves, whole plus 10 cloves garlic minced (5 g)
#   Analyse de : 1 lb ground beef (200 g)
#   Analyse de : 1 lb ground ham (1 portion)
#   Analyse de : 1 lb ground pork (100 g)
#   Analyse de : 1 lb ground veal (300 g)
#   Analyse de : 6 peaches, finely chopped (150 g)
#   Analyse de : 6 large pears, finely chopped (150 g)
#   Analyse de : 6 large tomatoes, finely chopped (1587.6000000000001 g)
#   Analyse de : 4 apples, finely chopped (150 g)
#   Analyse de : 1 plantain, finely chopped (150 g)
#   Analyse de : 2 cups finely chopped pineapple (150 g)
#   Analyse de : 2 1/2 cups prunes, pitted and finely chopped (1 portion)
#   Analyse de : 1 1/2 cups candied citron peel, finely chopped (1 portion)
#   Analyse de : 1 cup dried apricot, finely chopped (1 portion)
#   Analyse de : 1 cup raisins or currants (30 g)
#   Analyse de : 1 1/2 tablespoons fresh ground pepper (1 portion)
#   Analyse de : 1 tablespoon ground cinnamon (1 portion)
#   Analyse de : 1/2 teaspoon ground cloves (1 portion)
#   Analyse de : 1/2 teaspoon ground nutmeg (1 portion)
#   Analyse de : salt (1 portion)
#   Analyse de : 1 cup dry sherry (1 portion)
#   Analyse de : 1 cup dry white wine (1 portion)
#   Analyse de : 1/2 cup butter (14 g)
#   Analyse de : 10 bay leaves (1 portion)
#   Analyse de : 6 sprigs marjoram (1 portion)
#   Analyse de : 6 sprigs thyme (2 g)
#   Analyse de : Chiles (1 portion)
#   Analyse de : 32 medium poblano chiles (1 portion)
#   Analyse de : 1 cup vinegar (15 g)
#   Analyse de : 2 tablespoons salt (1 portion)
#   Analyse de : Nogada Sauce (1 portion)
#   Analyse de : 4 cups walnuts (30 g)
#   Analyse de : 2 cups almonds (30 g)
#   Analyse de : 1 1/2 cups whole milk (1 portion)
#   Analyse de : 1 cup crema fresca or heavy cream (240 g)
#   Analyse de : 1 cup dry sherry (1 portion)
#   Analyse de : 10 ounces goat cheese (30 g)
#   Analyse de : 8 ounces cream cheese (30 g)
#   Analyse de : 1/4 cup chopped onion (150 g)
#   Analyse de : 1/4 cup sugar (15 g)
#   Analyse de : 1 teaspoon salt (1 portion)
#   Analyse de : 1/4 teaspoon ground mexican cinnamon (1 portion)
#   Analyse de : pomegranate seeds, for garnish (1 portion)
#   Analyse de : fresh parsley, chopped, for garnish (5 g)
#
# Analyse du plat 35/83 : Pozole
# Erreur de conversion pour heart, liver, etc. removed: could not convert string to float: ''
# Erreur de conversion pour optional: could not convert string to float: ''
#   Analyse de : whole chicken (150.0 g)
#   Analyse de : 2 to 3 cans chicken broth (150 g)
#   Analyse de : 1 large onion (150 g)
#   Analyse de : 2 to 3 cloves (1 portion)
#   Analyse de : garlic (5 g)
#   Analyse de : 1 Tbsp. oregano (2 g)
#   Analyse de : 1/2 tsp. cumin (1 portion)
#   Analyse de : 1 Tbsp. chili powder (1 portion)
#   Analyse de : jalapenos (5.0 g)
#   Analyse de : salt and pepper (1 portion)
#   Analyse de : 2 (1000.0 g)
#   Analyse de : garnishes: chopped tomatoes, avocados, sliced green onion, cilantro, sour cream, grated cheese, jalapeno peppers, crushed tortilla chips, salsa, wedges of lime (150 g)
# Sauvegarde temporaire effectuée après 35 plats
#
# Analyse du plat 36/83 : Tamales
# Erreur de conversion pour pork-venison: could not convert string to float: ''
# Erreur de conversion pour heaping: could not convert string to float: ''
#   Analyse de : 5 lb. fresh masa (1 portion)
#   Analyse de : 1 tsp. baking powder and water (1 portion)
#   Analyse de : 1/2 can vegetable shortening (1 portion)
#   Analyse de : 2 heaping Tbsp. garlic salt (5 g)
#   Analyse de : 2 heaping Tbsp. chili powder (1 portion)
#   Analyse de : 6 lb. meat (5.0 g)
#   Analyse de : 3 Tbsp. chili powder-oregano (2 g)
#   Analyse de : 1/2 tsp. garlic powder (15.0 g)
#   Analyse de : 1 tsp. salt to taste (1 portion)
#
# Analyse du plat 37/83 : Cochinita Pibil
#   Analyse de : 2 pounds pork butt roast with bone (200 g)
#   Analyse de : 2 tablespoons achiote paste (1 portion)
#   Analyse de : 1/3 cup orange juice (1 portion)
#   Analyse de : 2/3 cup fresh-squeezed lemon juice (1 portion)
#   Analyse de : 2 habanero peppers, seeded and chopped (1 portion)
#   Analyse de : 1 teaspoon ground cumin (1 portion)
#   Analyse de : 1 teaspoon paprika (1 portion)
#   Analyse de : 1 teaspoon chili powder (1 portion)
#   Analyse de : 1 teaspoon ground coriander (5 g)
#   Analyse de : salt and pepper to taste (1 portion)
#   Analyse de : 1/2 cup red wine vinegar (15 g)
#   Analyse de : 2 red onions, sliced into rings (150 g)
#
# Analyse du plat 38/83 : Quesadillas
#   Analyse de : 12 (6.0 g)
#   Analyse de : 2 Tbsp. vegetable oil (15 g)
#   Analyse de : 2 c. shredded Monterey Jack or Cheddar cheese (226.8 g)
#
# Analyse du plat 39/83 : Ceviche
# Erreur de conversion pour raw: could not convert string to float: ''
#   Analyse de : 1 lb. whitefish fillets (150.0 g)
#   Analyse de : juice of 1 lime (1 portion)
#   Analyse de : 2 medium size tomatoes, peeled (150 g)
#   Analyse de : 2 green chilies, chopped (1 portion)
#   Analyse de : 1 small onion, thinly sliced (150 g)
#   Analyse de : 1/4 tsp. oregano (2 g)
#   Analyse de : 3 sprigs cilantro, chopped (5 g)
#   Analyse de : slices of 1 avocado (1 portion)
#   Analyse de : wedges of 1 tomato (150 g)
#
# Analyse du plat 40/83 : Paella Valenciana
#   Analyse de : 1 plumb chicken (150 g)
#   Analyse de : 1/2 c. butter (14 g)
#   Analyse de : 1 crushed clove garlic (5 g)
#   Analyse de : 2 c. rice (75 g)
#   Analyse de : 1/2 tsp. saffron (1 portion)
#   Analyse de : 4 c. hot chicken stock (150 g)
#   Analyse de : 2 lobsters (150 g)
#   Analyse de : 2 doz. shelled shrimp (100 g)
#   Analyse de : 2 doz. mussels (100 g)
#   Analyse de : 2 chorizo sausages, sliced (1 portion)
#   Analyse de : 1 c. diced pimentos (1 portion)
# Sauvegarde temporaire effectuée après 40 plats
#
# Analyse du plat 41/83 : Tortilla Española
# Erreur de conversion pour about 1 large: could not convert string to float: ''
#   Analyse de : 1 pound Yukon gold or small red potatoes, cut into 1/4-inch-thick slices (150 g)
#   Analyse de : 1 large red bell pepper (120 g)
#   Analyse de : 2 tablespoons extra-virgin olive oil, divided (15 g)
#   Analyse de : 2 1/2 cups thinly vertically sliced onion (150.0 g)
#   Analyse de : 1 tablespoon sherry vinegar (15 g)
#   Analyse de : 1/4 cup chopped fresh flat-leaf parsley (5 g)
#   Analyse de : 1/4 cup 2% reduced-fat milk (1 portion)
#   Analyse de : 1 tablespoon chopped fresh oregano (2 g)
#   Analyse de : 3/4 teaspoon salt (1 portion)
#   Analyse de : 1/2 teaspoon freshly ground black pepper (1 portion)
#   Analyse de : 6 large eggs, lightly beaten (50 g)
#   Analyse de : 3 large egg whites, lightly beaten (30 g)
#
# Analyse du plat 42/83 : Gazpacho
#   Analyse de : 1 c. tomato (150 g)
#   Analyse de : 1/2 c. red and green onion (150 g)
#   Analyse de : 1 c. cucumber (1 portion)
#   Analyse de : 1 c. red and green pepper (1 portion)
#   Analyse de : 1/3 c. Anaheim pepper (1 portion)
#   Analyse de : 1 c. celery (40 g)
#   Analyse de : 1/3 c. fresh parsley, finely chopped (5 g)
#   Analyse de : 2 cloves garlic, minced or crushed (5 g)
#   Analyse de : 2 c. tomato juice (150 g)
#   Analyse de : 3 Tbsp. red sherry wine vinegar (15 g)
#   Analyse de : 1/2 c. white wine (1 portion)
#   Analyse de : 1/2 Tbsp. cumin (1 portion)
#   Analyse de : 2 Tbsp. basil (5 g)
#   Analyse de : 1 Tbsp. lemon juice (1 portion)
#   Analyse de : 1 tsp. salt (1 portion)
#   Analyse de : 1/2 tsp. white pepper (1 portion)
#   Analyse de : 1 tsp. Worcestershire sauce (1 portion)
#   Analyse de : dash of Tabasco (1 portion)
#
# Analyse du plat 43/83 : Patatas Bravas
#   Analyse de : For the Sauce (1 portion)
#   Analyse de : 3 tablespoons olive oil (15 g)
#   Analyse de : 1 small onion, chopped (150 g)
#   Analyse de : 3 garlic cloves, chopped (5 g)
#   Analyse de : 1 (411.07500000000005 g)
#   Analyse de : 1 tablespoon tomato sauce (150 g)
#   Analyse de : 2 teaspoons sweet paprika (1 portion)
#   Analyse de : 1 teaspoon chili powder (1 portion)
#   Analyse de : 1/2 teaspoon cayenne pepper (1 portion)
#   Analyse de : 1/4 teaspoon crushed red pepper flakes (120 g)
#   Analyse de : 1 pinch sugar (15 g)
#   Analyse de : chopped fresh parsley, to garnish (5 g)
#   Analyse de : FOR THE POTATOES (150 g)
#   Analyse de : 2 lbs potatoes (150 g)
#   Analyse de : 2 tablespoons olive oil (15 g)
#
# Analyse du plat 44/83 : Churros
#   Analyse de : 1 1/2 c. Bisquick (1 portion)
#   Analyse de : 1 c. water (1 portion)
#   Analyse de : 1 egg (1 portion)
#   Analyse de : 1/2 tsp. cinnamon (1 portion)
#   Analyse de : 1 Tbsp. sugar plus a little extra (15 g)
#   Analyse de : vegetable oil (15 g)
#
# Analyse du plat 45/83 : Croquetas
#   Analyse de : 2 eggs, beaten (50 g)
#   Analyse de : 4 tablespoons flour (120 g)
#   Analyse de : 1 pinch paprika (1 portion)
#   Analyse de : 3 tablespoons olive oil (15 g)
#   Analyse de : salt and pepper (1 portion)
#   Analyse de : 1 cup milk (1 portion)
#   Analyse de : 1/2 lb ham (1 portion)
#   Analyse de : 1/2 sliced onion (150 g)
#   Analyse de : 2 cups breadcrumbs (30 g)
# Sauvegarde temporaire effectuée après 45 plats
#
# Analyse du plat 46/83 : Pulpo a la Gallega
# Erreur de conversion pour about 1/2" in thickness or less: could not convert string to float: '2"'
# Erreur de conversion pour about, or more: could not convert string to float: ''
#   Analyse de : 2 lbs octopus (100 g)
#   Analyse de : 1 onion (150 g)
#   Analyse de : 2 bay leaves (1 portion)
#   Analyse de : 2 larger potatoes, boiled and sliced diagonally into rounds (50.0 ml)
#   Analyse de : 1 teaspoon hot paprika, to taste (5.0 g)
#   Analyse de : sea salt (1 portion)
#   Analyse de : extra virgin olive oil (15 g)
#
# Analyse du plat 47/83 : Albondigas
#   Analyse de : 1 1/2 lb. lean ground beef (200 g)
#   Analyse de : 1 c. bread crumbs (30 g)
#   Analyse de : dash of pepper (1 portion)
#   Analyse de : 1 egg, beaten (1 portion)
#   Analyse de : 1 1/2 tsp. salt (1 portion)
#   Analyse de : 1 Tbsp. chopped onions (150 g)
#
# Analyse du plat 48/83 : Moussaka
#   Analyse de : 2 large eggplant (1 portion)
#   Analyse de : 2 lb. extra-lean ground beef or lamb (200 g)
#   Analyse de : 1 c. chopped onion (150 g)
#   Analyse de : 1 clove garlic, minced (5 g)
#   Analyse de : 1 c. low-sodium tomato sauce (150 g)
#   Analyse de : 3/4 c. dry red wine (1 portion)
#   Analyse de : 2 Tbsp. snipped fresh parsley (5 g)
#   Analyse de : 1/4 tsp. dried oregano (2 g)
#   Analyse de : 1/4 tsp. plus dash of ground cinnamon (1 portion)
#   Analyse de : 1 Tbsp. polyunsaturated margarine (1 portion)
#   Analyse de : 2 c. skim milk (1 portion)
#   Analyse de : 1/2 c. low-fat cottage cheese (30 g)
#   Analyse de : 3 Tbsp. arrowroot starch (1 portion)
#   Analyse de : 1/4 c. egg substitute (1 portion)
#
# Analyse du plat 49/83 : Souvlaki
#   Analyse de : 1 lemon, juiced (1 portion)
#   Analyse de : 1/4 cup olive oil (15 g)
#   Analyse de : 1/4 cup soy sauce (15 g)
#   Analyse de : 1 teaspoon dried oregano (2 g)
#   Analyse de : 3 cloves garlic, crushed (5 g)
#   Analyse de : 4 pounds pork tenderloin, cut into 1 inch cubes (200 g)
#   Analyse de : 2 medium yellow onions, cut into 1 inch pieces (150 g)
#   Analyse de : 2 green bell peppers, cut into 1 inch pieces (120 g)
#   Analyse de : skewers (1 portion)
#
# Analyse du plat 50/83 : Gyros
#   Analyse de : 1/4 cup chopped red onion (150 g)
#   Analyse de : 1 tablespoon minced garlic (5 g)
#   Analyse de : 1 tablespoon dried marjoram (1 portion)
#   Analyse de : 1 tablespoon ground dried rosemary (2 g)
#   Analyse de : 2 teaspoons kosher salt (1 portion)
#   Analyse de : 1/2 teaspoon freshly ground black pepper (1 portion)
#   Analyse de : 1 pound 93%-lean ground beef (200 g)
#   Analyse de : 1 pound ground lamb (100 g)
# Sauvegarde temporaire effectuée après 50 plats
#
# Analyse du plat 51/83 : Dolmades
#   Analyse de : 1/2 lb. ground beef (200 g)
#   Analyse de : 1 onion, chopped fine (150 g)
#   Analyse de : 2 cloves garlic, chopped fine (5 g)
#   Analyse de : 1 tsp. parsley, chopped fine (5 g)
#   Analyse de : 2 tsp. ginger, chopped fine (15 g)
#   Analyse de : 1 heaping tsp. curry powder (1 portion)
#   Analyse de : 1 beaten egg (1 portion)
#   Analyse de : 1/2 c. currants (1 portion)
#   Analyse de : 1/2 c. toasted pine nuts or slivered almonds (30 g)
#   Analyse de : 1 c. cooked rice (75 g)
#   Analyse de : salt and pepper to taste (1 portion)
#   Analyse de : 1 pt. jar grape leaves in salt brine (1 portion)
#   Analyse de : juice of 4 limes (1 portion)
#   Analyse de : 1/4 c. olive oil (15 g)
#
# Analyse du plat 52/83 : Tzatziki
#   Analyse de : 3 c. cottage cheese (30 g)
#   Analyse de : 1/3 c. sour cream (240 g)
#   Analyse de : 2 small cloves garlic (5 g)
#   Analyse de : 1/3 c. fresh unpeeled cucumber, grated (1 portion)
#   Analyse de : salt (1 portion)
#
# Analyse du plat 53/83 : Spanakopita
#   Analyse de : 2 lb. spinach (150 g)
#   Analyse de : 1 lb. phyllo (1 portion)
#   Analyse de : 7 eggs (50 g)
#   Analyse de : 1/2 lb. Feta cheese (30 g)
#   Analyse de : 1 onion (150 g)
#   Analyse de : olive oil (15 g)
#   Analyse de : salt and pepper (1 portion)
#   Analyse de : oregano (2 g)
#   Analyse de : butter (14 g)
#
# Analyse du plat 54/83 : Saganaki
# Erreur de conversion pour for dredging: could not convert string to float: ''
#   Analyse de : 8 ounces kasseri cheese (30 g)
#   Analyse de : flour (150.0 g)
#   Analyse de : 3 tablespoons olive oil (15 g)
#   Analyse de : ouzo (1 portion)
#   Analyse de : 1/2 lemon (1 portion)
#   Analyse de : 1 tablespoon fresh oregano (2 g)
#   Analyse de : fresh cherry tomatoes (150 g)
#   Analyse de : pita bread, wedges (30 g)
#   Analyse de : kalamata olive (1 portion)
#
# Analyse du plat 55/83 : Pastitsio
#   Analyse de : 1 c. onion, chopped (150 g)
#   Analyse de : 1 lb. ground turkey (115 g)
#   Analyse de : 1 (226.8 g)
#   Analyse de : 1/2 tsp. cinnamon (1 portion)
#   Analyse de : 1/2 tsp. oregano (2 g)
#   Analyse de : 1/4 tsp. nutmeg (1 portion)
#   Analyse de : 1/2 tsp. salt (1 portion)
#   Analyse de : 1/4 tsp. pepper (1 portion)
#   Analyse de : 2 c. uncooked elbow macaroni (85 g)
#   Analyse de : 1/4 c. flour (120 g)
#   Analyse de : 1 egg (1 portion)
#   Analyse de : 1 egg white (1 portion)
#   Analyse de : 1/4 c. Parmesan cheese (30 g)
# Sauvegarde temporaire effectuée après 55 plats
#
# Analyse du plat 56/83 : Baklava
#   Analyse de : 10 oz. walnuts, finely chopped (30 g)
#   Analyse de : 7 oz. almonds, finely chopped (30 g)
#   Analyse de : 2 1/2 tsp. ground cinnamon (1 portion)
#   Analyse de : 1/4 tsp. ground cloves (1 portion)
#   Analyse de : 1/3 c. sugar (15 g)
#   Analyse de : 3/4 c. butter, melted (14 g)
#   Analyse de : 30 sheets filo pastry (1 portion)
#
# Analyse du plat 57/83 : Greek Salad
# Erreur de conversion pour optional: could not convert string to float: ''
#   Analyse de : 1 small head lettuce (50 g)
#   Analyse de : 1 small cucumber, sliced (1 portion)
#   Analyse de : 1 or 2 tomatoes, cut as desired (150 g)
#   Analyse de : 1 green pepper, cut into strips (1 portion)
#   Analyse de : 1 small onion, sliced or 4 scallions, chopped (150 g)
#   Analyse de : 2 stalks celery, chopped (40 g)
#   Analyse de : 6 radishes, sliced (1 portion)
#   Analyse de : 1/4 c. parsley, finely cut with scissors (5 g)
#   Analyse de : 1/2 c. crumbled Feta cheese (30 g)
#   Analyse de : Calamata or Greek black olives (1 portion)
#   Analyse de : anchovies (5.0 g)
#
# Analyse du plat 58/83 : Butter Chicken
#   Analyse de : 2 lb. boneless chicken (150 g)
#   Analyse de : 1 onion, grated (150 g)
#   Analyse de : 1/4 tsp. each, garlic and ginger paste (5 g)
#   Analyse de : 4 tomatoes, fully ripened (150 g)
#   Analyse de : 1/2 cup pure cream (240 g)
#   Analyse de : 2 Tbsp. tomato sauce (150 g)
#   Analyse de : 1 Tbsp. butter (14 g)
#   Analyse de : 1 tsp. cayenne pepper (1 portion)
#   Analyse de : 2 cloves (1 portion)
#   Analyse de : 4-5 cardamoms (1 portion)
#   Analyse de : 2 sticks cinnamon (1 portion)
#   Analyse de : 2 green chilies (1 portion)
#   Analyse de : Salt to tate (1 portion)
#   Analyse de : Orange-red food color (1 portion)
#
# Analyse du plat 59/83 : Biryani
# Erreur de conversion pour long grain rice: could not convert string to float: ''
# Erreur de conversion pour cilantro: could not convert string to float: ''
#   Analyse de : 1/2 lb. meat or chicken, cut in pieces (150 g)
#   Analyse de : 1/2 lb. Bhasmathi rice (5.0 g)
#   Analyse de : 1/2 c. thick yogurt (1 portion)
#   Analyse de : 1 big onion, chopped in thin slices (150 g)
#   Analyse de : 6 tsp. ghee or oil (15 g)
#   Analyse de : 2 sticks cinnamon (1 portion)
#   Analyse de : 4 cloves (1 portion)
#   Analyse de : 1 cardamon (1 portion)
#   Analyse de : 1 tsp. paste of ginger and garlic (5 g)
#   Analyse de : 2 green chillies (1 portion)
#   Analyse de : 1/2 tsp. chili powder (1 portion)
#   Analyse de : 1/2 bunch mint and coriander (5.0 g)
#
# Analyse du plat 60/83 : Samosas
# Erreur de conversion pour optional: could not convert string to float: ''
#   Analyse de : beef samosas (200 g)
#   Analyse de : 1 tablespoon oil (15 g)
#   Analyse de : 1 kg lean ground beef (200 g)
#   Analyse de : 2 onions, diced fine (150 g)
#   Analyse de : 3 garlic cloves, minced (5 g)
#   Analyse de : 2 teaspoons grated fresh ginger (15 g)
#   Analyse de : 4 -5 tablespoons madras curry paste (15 g)
#   Analyse de : 1 teaspoon paprika (1 portion)
#   Analyse de : 1/2 cup fresh coriander, chopped fine (5 g)
#   Analyse de : 1/4 - 1/2 teaspoon chili powder (5.0 g)
#   Analyse de : 1 teaspoon salt (1 portion)
#   Analyse de : 1/2 teaspoon pepper, black course ground (1 portion)
#   Analyse de : pastry dough (1 portion)
#   Analyse de : 3 cups plain flour (120 g)
#   Analyse de : 1/2 teaspoon salt (1 portion)
#   Analyse de : water (1 portion)
#   Analyse de : 2 tablespoons peanut oil (15 g)
#   Analyse de : oil, for frying (15 g)
# Sauvegarde temporaire effectuée après 60 plats
#
# Analyse du plat 61/83 : Dal Makhani
# Erreur de conversion pour whole black beans: could not convert string to float: ''
# Erreur de conversion pour rajmah: could not convert string to float: ''
# Erreur de conversion pour zeera: could not convert string to float: ''
# Erreur de conversion pour ghee: could not convert string to float: ''
#   Analyse de : 1 1/2 cups Urad Dal (5.0 g)
#   Analyse de : 1/2 cup red kidney beans (5.0 g)
#   Analyse de : 350 -400 g whipping cream, chilled (240 g)
#   Analyse de : 4 tomatoes, pureed (150 g)
#   Analyse de : 6 garlic flakes (5 g)
#   Analyse de : 1 teaspoon cumin seed (5.0 g)
#   Analyse de : salt (1 portion)
#   Analyse de : red chili powder (1 portion)
#   Analyse de : 4 tablespoons clarified butter (50.0 g)
#
# Analyse du plat 62/83 : Naan
# Erreur de conversion pour optional: could not convert string to float: ''
#   Analyse de : 1 (7.0875 g)
#   Analyse de : 1 cup warm water (1 portion)
#   Analyse de : 1/4 cup white sugar (15 g)
#   Analyse de : 3 tablespoons milk (1 portion)
#   Analyse de : 1 egg, beaten (1 portion)
#   Analyse de : 2 teaspoons salt (1 portion)
#   Analyse de : 4 1/2 cups bread flour (120 g)
#   Analyse de : 2 teaspoons minced garlic (15.0 g)
#   Analyse de : 1/4 cup butter, melted (14 g)
#
# Analyse du plat 63/83 : Tandoori Chicken
# Erreur de conversion pour optional: could not convert string to float: ''
# Erreur de conversion pour available at indian grocery stores: could not convert string to float: ''
#   Analyse de : 2 to 3 lb. assorted chicken parts (150 g)
#   Analyse de : 1 onion (150.0 g)
#   Analyse de : 1 pt. plain yogurt (1 portion)
#   Analyse de : dry tandoori mix (5.0 g)
#
# Analyse du plat 64/83 : Palak Paneer
# Erreur de conversion pour clarified butter: could not convert string to float: ''
# Erreur de conversion pour hing: could not convert string to float: ''
# Erreur de conversion pour methi powder: could not convert string to float: ''
#   Analyse de : cheesecloth (30 g)
#   Analyse de : 1 gallon whole milk (1 portion)
#   Analyse de : 1/2 cup lemon juice (1 portion)
#   Analyse de : 1 bunch fresh spinach leaves (150 g)
#   Analyse de : 1 pound tomatoes (150 g)
#   Analyse de : 1/4 cup ghee (5.0 g)
#   Analyse de : 1 teaspoon turmeric powder (1 portion)
#   Analyse de : 1 teaspoon ground red chile pepper (1 portion)
#   Analyse de : 1/4 teaspoon asafoetida powder (5.0 g)
#   Analyse de : 1 1/2 teaspoons salt, or to taste (1 portion)
#   Analyse de : 2 tablespoons heavy whipping cream, or more as needed (240 g)
#   Analyse de : 1/4 teaspoon ground fenugreek seeds (5.0 g)
#
# Analyse du plat 65/83 : Vindaloo
# Erreur de conversion pour peeled and 1-inch cubed: could not convert string to float: ''
# Erreur de conversion pour white creamy type in a can or a few ounces of dessicated coconut: could not convert string to float: ''
# Erreur de conversion pour finely ground: could not convert string to float: ''
# Erreur de conversion pour finely ground: could not convert string to float: ''
# Erreur de conversion pour finely ground: could not convert string to float: ''
# Erreur de conversion pour finely ground: could not convert string to float: ''
# Erreur de conversion pour hot portugal type, pureed: could not convert string to float: ''
# Erreur de conversion pour finely ground: could not convert string to float: ''
# Erreur de conversion pour may sub with cayenne or add cayenne with the chili powder: could not convert string to float: ''
# Erreur de conversion pour finely diced: could not convert string to float: ''
#   Analyse de : 2 lbs boneless skinless chicken (1.0 g)
#   Analyse de : 1/2 cup vinegar (15 g)
#   Analyse de : 2 medium potatoes (5.0 g)
#   Analyse de : 4 tablespoons vegetable oil (15 g)
#   Analyse de : 1 large onion (5.0 g)
#   Analyse de : 6 large garlic cloves (5.0 g)
#   Analyse de : 2 ounces fresh gingerroot (5.0 g)
#   Analyse de : 2 large tomatoes (5.0 g)
#   Analyse de : 8 ounces unsweetened coconut milk (250.0 ml)
#   Analyse de : 3 cloves (5.0 g)
#   Analyse de : 1 1/2 teaspoons cardamom seeds (5.0 g)
#   Analyse de : 1 ounce cassia (2.5 g)
#   Analyse de : 2 1/2 teaspoons cumin seeds (5.0 g)
#   Analyse de : 1 teaspoon fenugreek seeds (5.0 g)
#   Analyse de : 1/2 teaspoon asafoetida powder (1 portion)
#   Analyse de : 9 hot peppers (2.5 g)
#   Analyse de : 1 teaspoon black mustard seeds (5.0 g)
#   Analyse de : 2 bay leaves (1 portion)
#   Analyse de : 1 teaspoon turmeric (1 portion)
#   Analyse de : 1 teaspoon chili powder (5.0 g)
#   Analyse de : 2 ounces fresh cilantro (5.0 g)
# Sauvegarde temporaire effectuée après 65 plats
#
# Analyse du plat 66/83 : Korma
#   Analyse de : 1 1/2 tablespoons vegetable oil (15 g)
#   Analyse de : 1 small white onion, diced (150 g)
#   Analyse de : 4 garlic cloves, minced (5 g)
#   Analyse de : 1 teaspoon fresh gingerroot, minced (15 g)
#   Analyse de : 2 small yukon gold potatoes, cubed (150 g)
#   Analyse de : 4 carrots, cubed (120 g)
#   Analyse de : 1 fresh jalapeno pepper, seeded and sliced (1 portion)
#   Analyse de : 6 tablespoons unsalted cashews, ground (30 g)
#   Analyse de : 1 (113.4 g)
#   Analyse de : 1 1/2 tablespoons hot curry powder (1 portion)
#   Analyse de : 1 teaspoon cardamom (1 portion)
#   Analyse de : 1 teaspoon garam masala (1 portion)
#   Analyse de : 2 teaspoons sea salt (1 portion)
#   Analyse de : 1 cup frozen green pea (1 portion)
#   Analyse de : 1/2 green bell pepper, chopped (120 g)
#   Analyse de : 1/2 red bell pepper, chopped (120 g)
#   Analyse de : 1 (425.25 g)
#   Analyse de : cilantro (5.0 g)
#
# Analyse du plat 67/83 : Pad Thai
#   Analyse de : 8 oz. dry rice noodles (75 g)
#   Analyse de : 1/4 c. fish sauce (15 g)
#   Analyse de : 2 Tbsp. rice wine vinegar (75 g)
#   Analyse de : 2 Tbsp. sugar (15 g)
#   Analyse de : 1/4 lb. peeled and de-veined raw shrimp, halved lengthwise (100 g)
#   Analyse de : 1/4 lb. ground pork (100 g)
#   Analyse de : 1/4 tsp. cayenne (1 portion)
#   Analyse de : 3 Tbsp. peanut oil (15 g)
#   Analyse de : 3 Tbsp. minced garlic (5 g)
#   Analyse de : 2 large eggs (50 g)
#   Analyse de : 2 c. bean sprouts (50 g)
#   Analyse de : 2 c. sliced green onions (150 g)
#   Analyse de : 1/4 c. chopped roasted unsalted peanuts (30 g)
#   Analyse de : 1/4 c. minced fresh cilantro (5 g)
#   Analyse de : 1 Tbsp. fresh lime juice (1 portion)
#
# Analyse du plat 68/83 : Tom Yum Goong
#   Analyse de : 4 cups water (1 portion)
#   Analyse de : 1 cup shrimp (100 g)
#   Analyse de : 5 mushrooms (15 g)
#   Analyse de : 1 -2 lime (1 portion)
#   Analyse de : 1 lemongrass (15 g)
#   Analyse de : 3 kaffir lime leaves (2 g)
#   Analyse de : 2 tablespoons fish sauce (15 g)
#   Analyse de : 5 sprigs cilantro (5 g)
#   Analyse de : 3 chili peppers (1 portion)
#   Analyse de : 1 tablespoon chili paste (1 portion)
#
# Analyse du plat 69/83 : Green Curry
# Erreur de conversion pour breast: could not convert string to float: ''
#   Analyse de : 1 packet Store-bought green curry paste (15 g)
#   Analyse de : 1 can, 400 ml Canned coconut milk or cream (240 g)
#   Analyse de : 2 tbsp Coconut powder (1 portion)
#   Analyse de : 133 ml Milk (1 portion)
#   Analyse de : 1 dash Fish sauce (15 g)
#   Analyse de : 1 Salt (1 portion)
#   Analyse de : 1 Onion (150 g)
#   Analyse de : 1 Carrot (120 g)
#   Analyse de : 2 Potatoes (150 g)
#   Analyse de : 1 Chicken (150.0 g)
#   Analyse de : 1/4 Bamboo shoot (100 g)
#   Analyse de : 1 Red bell pepper (120 g)
#
# Analyse du plat 70/83 : Massaman Curry
# Erreur de conversion pour about 2: could not convert string to float: ''
# Erreur de conversion pour about 4: could not convert string to float: ''
# Erreur de conversion pour about 4: could not convert string to float: ''
#   Analyse de : 1 tablespoon cooking oil (15 g)
#   Analyse de : 1 onion, chopped (150 g)
#   Analyse de : 2 garlic cloves, minced (5 g)
#   Analyse de : 1 teaspoon fresh ginger, chopped (15 g)
#   Analyse de : 1 teaspoon Chinese five spice powder (1 portion)
#   Analyse de : 1 teaspoon ground cumin (1 portion)
#   Analyse de : 1/4 teaspoon cayenne (1 portion)
#   Analyse de : 1/4 teaspoon turmeric (1 portion)
#   Analyse de : 1 teaspoon salt (1 portion)
#   Analyse de : 1 cup low sodium chicken broth (150 g)
#   Analyse de : 1/2 cup canned unsweetened coconut milk or 1/2 cup heavy cream (240 g)
#   Analyse de : 1/2 lb boiling potato, peeled and cut into 1/2-inch pieces (50.0 ml)
#   Analyse de : 1 1/3 lbs boneless skinless chicken breasts, cut into 12-inch pieces (150.0 g)
#   Analyse de : 1/2 cup peanuts, chopped (30 g)
#   Analyse de : 1/2 lb plum tomato, cut into wedges (5.0 g)
#   Analyse de : 3 tablespoons cilantro, chopped (5 g)
# Sauvegarde temporaire effectuée après 70 plats
#
# Analyse du plat 71/83 : Tom Kha Gai
#   Analyse de : 3 cups chicken broth (150 g)
#   Analyse de : 1 (396.90000000000003 g)
#   Analyse de : 1/4 cup sweet red chile sauce (1 portion)
#   Analyse de : 3 tablespoons lime juice (1 portion)
#   Analyse de : 2 tablespoons fish sauce (15 g)
#   Analyse de : 2 tablespoons brown sugar (15 g)
#   Analyse de : 1 (1.5 g)
#   Analyse de : 10 kaffir lime leaves, torn and bruised (2 g)
#   Analyse de : 1 1/2 pounds skinless, boneless chicken breast halves - cut into strips (150 g)
#   Analyse de : 1 (425.25 g)
#   Analyse de : 1 cup coarsely chopped onion (150 g)
#   Analyse de : 1 zucchini, sliced (200 g)
#   Analyse de : 1 lemongrass stalk, chopped (15 g)
#   Analyse de : 1 bunch fresh basil, chopped (5 g)
#
# Analyse du plat 72/83 : Red Curry
#   Analyse de : lite coconut milk or 14 ounces can of light (400 g)
#   Analyse de : 1 red pepper large (120 g)
#   Analyse de : 1 tablespoon red curry paste heaping of (15 g)
#   Analyse de : 1 onion small (150 g)
#   Analyse de : 3 cloves garlic depending on what you like (5 g)
#   Analyse de : 2 red potatoes smalls (150 g)
#   Analyse de : 2 zucchinis (200 g)
#   Analyse de : 1/2 cup chicken broth (150 g)
#   Analyse de : 1 teaspoon lemon juice (1 portion)
#   Analyse de : 1 teaspoon Sriracha more if you like it really spicy (1 portion)
#   Analyse de : 1 pound chicken or or beef, or more vegetables (150 g)
#
# Analyse du plat 73/83 : Pad See Ew
#   Analyse de : 6 None chicken drumsticks (150 g)
#   Analyse de : 1/2 cup chicken stock (150 g)
#   Analyse de : 2 tbsp soy sauce (15 g)
#   Analyse de : 2 tbsp oyster sauce (15 g)
#   Analyse de : 1 None medium red onion, halved, cut into thin wedges (150 g)
#   Analyse de : 6 oz broccolini, cut into 1 inch pieces (100 g)
#   Analyse de : 2 cloves garlic, minced (5 g)
#   Analyse de : 1 inch fresh ginger, peeled, cut into matchsticks (15 g)
#   Analyse de : 16 oz fresh rice vermicelli noodles, soaked in boiling water for 2-3 mins, drained (75 g)
#   Analyse de : 2 bunches baby bok choy, roughly shredded (100 g)
#   Analyse de : 5.25 oz snow peas, trimmed (80 g)
#   Analyse de : 4 oz bean sprouts, rinsed (50 g)
#   Analyse de : 1 None fresh long red chili, thinly sliced (1 portion)
#
# Analyse du plat 74/83 : Hamburger
#   Analyse de : 1 lb. hamburger (1 portion)
#   Analyse de : 1 can golden mushroom soup (15 g)
#   Analyse de : flour (120 g)
#   Analyse de : 2 to 3 tsp. oil (15 g)
#
# Analyse du plat 75/83 : Hot Dog
#   Analyse de : 2 lb. wieners (1 portion)
#   Analyse de : 3/4 c. vinegar (15 g)
#   Analyse de : 1 1/2 c. catsup (1 portion)
#   Analyse de : 1/2 c. brown sugar (15 g)
#   Analyse de : 1 1/2 tsp. minced onion (150 g)
# Sauvegarde temporaire effectuée après 75 plats
#
# Analyse du plat 76/83 : Mac and Cheese
#   Analyse de : 2 Tbsp. butter, melted in 9 x 13 pan (14 g)
#   Analyse de : 2 c. raw macaroni (85 g)
#   Analyse de : 3 c. sharp shredded cheese (30 g)
#
# Analyse du plat 77/83 : BBQ Ribs
#   Analyse de : Country style ribs (1 portion)
#   Analyse de : Your favorite BBQ sauce (1 portion)
#   Analyse de : Salt and pepper to taste (1 portion)
#
# Analyse du plat 78/83 : Fried Chicken
#   Analyse de : 2 c. flour (120 g)
#   Analyse de : 1 c. meal (1 portion)
#   Analyse de : 1 Tbsp. salt (1 portion)
#   Analyse de : 1 Tbsp. black pepper (1 portion)
#   Analyse de : 1 c. shortening (1 portion)
#   Analyse de : 1 whole chicken, cut up (150 g)
#
# Analyse du plat 79/83 : Apple Pie
#   Analyse de : 6 to 7 apples, sliced (150 g)
#   Analyse de : 1 c. sugar (15 g)
#   Analyse de : 2 Tbsp. flour (120 g)
#   Analyse de : 1 tsp. cinnamon (1 portion)
#   Analyse de : dash of salt and nutmeg (1 portion)
#
# Analyse du plat 80/83 : Cheeseburger
#   Analyse de : 1 beaten egg (1 portion)
#   Analyse de : 1 (304.7625 g)
#   Analyse de : 1/2 c. soft bread crumbs (30 g)
#   Analyse de : 1/2 c. chopped dill pickles (1 portion)
#   Analyse de : 1/4 c. chopped onions (150 g)
#   Analyse de : 1/4 tsp. salt (1 portion)
#   Analyse de : 1/8 tsp. pepper (1 portion)
#   Analyse de : 1 1/2 lb. ground beef (200 g)
# Sauvegarde temporaire effectuée après 80 plats
#
# Analyse du plat 81/83 : Buffalo Wings
#   Analyse de : 12 pieces chicken wings - drumettes (150 g)
#   Analyse de : 2 Tbsp. margarine - melted (1 portion)
#   Analyse de : 2 Tbsp. hot sauce (15 g)
#   Analyse de : 1 1/2 Tbsp. red wine vinegar (15 g)
#
# Analyse du plat 82/83 : Clam Chowder
# Erreur de conversion pour reserve 1 c. clam juice: could not convert string to float: ''
#   Analyse de : 6 to 8 lean slices diced bacon (30 g)
#   Analyse de : 2 c. diced, cooked potatoes (150 g)
#   Analyse de : 1 c. diced onion (150 g)
#   Analyse de : 2 cans minced clams, drained (5.0 g)
#   Analyse de : 2 c. half and half (1 portion)
#   Analyse de : 1 c. water (1 portion)
#   Analyse de : 2 Tbsp. butter (14 g)
#   Analyse de : salt and pepper to taste (1 portion)
#
# Analyse du plat 83/83 : Philly Cheesesteak
# Erreur de conversion pour freeze and use meat slicer to thinnest cut: could not convert string to float: ''
# Erreur de conversion pour sliced lengthwise to form a cradle, similar to a hot dog bun.: could not convert string to float: ''
# Erreur de conversion pour diced, wit: could not convert string to float: ''
# Erreur de conversion pour optional: could not convert string to float: ''
# Erreur de conversion pour optional: could not convert string to float: ''
#   Analyse de : 24 ounces boneless rib-eye steaks (5.0 g)
#   Analyse de : 4 crusty Italian rolls (5.0 g)
#   Analyse de : 1 large Spanish onion (150.0 g)
#   Analyse de : 6 tablespoons soya oil (15 g)
#   Analyse de : Cheez Whiz (1 portion)
#   Analyse de : sauteed mushroom (5.0 g)
#   Analyse de : sauteed red & green sweet pepper (2.5 g)
#
# Aperçu des résultats avant sauvegarde:
#                  Plat    Pays       Catégorie  Protéines (g)  Lipides (g)  \
# 0            Couscous  FRANCE  Plat principal           0.00         0.00
# 1               Pizza  FRANCE       Fast-food           3.69         2.09
# 2        Steak-frites  FRANCE  Plat principal         283.41       198.00
# 3  Blanquette de veau  FRANCE          Viande          63.18       196.73
# 4   Boeuf bourguignon  FRANCE          Viande         114.30        59.93
#
#    Glucides (g)  Calories (kcal)  Fibres (g)  Sucres (g)  Sodium (mg)
# 0          0.00             0.00        0.00           0         0.00
# 1         19.66            50.00        0.00           0        39.60
# 2         30.56          3012.97        0.60           0      4081.77
# 3         96.08          2532.11       12.92           0      1351.63
# 4        199.31          1126.97       12.24           0      1636.40
#
# Analyse terminée avec succès!
